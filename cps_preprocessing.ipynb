# %%
import pandas as pd

# %%
data = pd.read_csv('cps_00006.csv')
print(data.head())
# Out:
#    YEAR  SERIAL  MONTH  REGION  STATEFIP  COUNTY  AGE  SEX  RACE  HISPAN  \
# 0  2013       1      1      32         1       0   79    1   100       0
# 1  2013       1      1      32         1       0   65    2   100       0
# 2  2013       1      1      32         1       0   28    2   100       0
# 3  2013       2      1      32         1       0   32    1   100       0
# 4  2013       2      1      32         1       0   33    2   100       0
#
#    EMPSTAT  WHYUNEMP  EDUC  DIFFANY
# 0       36         0   111        1
# 1       36         0   111        1
# 2       10         0   111        1
# 3       36         0    73        2
# 4       36         0    73        1

# %%
# Replace the values of 1 and 2 in the "sex" variable with "male" and "female", respectively
data["SEX"] = data["SEX"].replace({1: "male", 2: "female"})

# View the updated dataset
print(data.head())
data.to_csv("updated_Annual.csv")
# Out:
#    YEAR  SERIAL  MONTH  REGION  STATEFIP  COUNTY  AGE     SEX  RACE  HISPAN  \
# 0  2013       1      1      32         1       0   79    male   100       0
# 1  2013       1      1      32         1       0   65  female   100       0
# 2  2013       1      1      32         1       0   28  female   100       0
# 3  2013       2      1      32         1       0   32    male   100       0
# 4  2013       2      1      32         1       0   33  female   100       0
#
#    EMPSTAT  WHYUNEMP  EDUC  DIFFANY
# 0       36         0   111        1
# 1       36         0   111        1
# 2       10         0   111        1
# 3       36         0    73        2
# 4       36         0    73        1

# %%
data["REGION"] = data["REGION"].replace({11: "NORTHEAST",12: "NORTHEAST",21: "MIDWEST", 22:"MIDWEST", 31: "SOUTH", 32: "SOUTH", 33: "SOUTH", 41: "WEST", 42:"WEST", 97: 'UNKNOWN'})

# View the updated dataset
print(data.head())
data.to_csv('updated_Annual.csv')
# Out:
#    YEAR  SERIAL  MONTH REGION  STATEFIP  COUNTY  AGE     SEX  RACE  HISPAN  \
# 0  2013       1      1  SOUTH         1       0   79    male   100       0
# 1  2013       1      1  SOUTH         1       0   65  female   100       0
# 2  2013       1      1  SOUTH         1       0   28  female   100       0
# 3  2013       2      1  SOUTH         1       0   32    male   100       0
# 4  2013       2      1  SOUTH         1       0   33  female   100       0
#
#    EMPSTAT  WHYUNEMP  EDUC  DIFFANY
# 0       36         0   111        1
# 1       36         0   111        1
# 2       10         0   111        1
# 3       36         0    73        2
# 4       36         0    73        1

# %%
data['DIFFANY'] = data['DIFFANY'].replace({0:'UNKNOWN', 1:'NO', 2:'YES'})

# View the updated dataset
print(data.head())
data.to_csv('updated_Annual.csv')
# Out:
#    YEAR  SERIAL  MONTH REGION  STATEFIP  COUNTY  AGE     SEX  RACE  HISPAN  \
# 0  2013       1      1  SOUTH         1       0   79    male   100       0
# 1  2013       1      1  SOUTH         1       0   65  female   100       0
# 2  2013       1      1  SOUTH         1       0   28  female   100       0
# 3  2013       2      1  SOUTH         1       0   32    male   100       0
# 4  2013       2      1  SOUTH         1       0   33  female   100       0
#
#    EMPSTAT  WHYUNEMP  EDUC DIFFANY
# 0       36         0   111      NO
# 1       36         0   111      NO
# 2       10         0   111      NO
# 3       36         0    73     YES
# 4       36         0    73      NO

# %%
race_labels = {
    100: "White",
    200: "Black",
    300: "Others",
    651: "Asian",
    652: "Hawaiian/Pacific Islander",
    801: "Others",
    802: "Others",
    803: "Others",
    804: "Others",
    805: "Others",
    806: "Others",
    807: "Others",
    808: "Others",
    809: "Others",
    810: "Others",
    811: "Others",
    812: "Others",
    813: "Others",
    814: "Others",
    815: "Others",
    816: "Others",
    817: "Others",
    818: "Others",
    819: "Others",
    820: "Others",
    830: "Others",
    700: "Others",
    650: "Others",
}

# %%
data["RACE"] = data["RACE"].map(race_labels)
print(data.head())
data.to_csv('updated_Annual.csv')
# Out:
#    YEAR  SERIAL  MONTH REGION  STATEFIP  COUNTY  AGE     SEX   RACE  HISPAN  \
# 0  2013       1      1  SOUTH         1       0   79    male  White       0
# 1  2013       1      1  SOUTH         1       0   65  female  White       0
# 2  2013       1      1  SOUTH         1       0   28  female  White       0
# 3  2013       2      1  SOUTH         1       0   32    male  White       0
# 4  2013       2      1  SOUTH         1       0   33  female  White       0
#
#    EMPSTAT  WHYUNEMP  EDUC DIFFANY
# 0       36         0   111      NO
# 1       36         0   111      NO
# 2       10         0   111      NO
# 3       36         0    73     YES
# 4       36         0    73      NO

# %%
state_labels = {

1:	"Alabama",
2:	"Alaska",
4:	"Arizona",
5:	"Arkansas",
6:	"California",
8:	"Colorado",
9:	"Connecticut",
10:	"Delaware",
11:	"District of Columbia",
12:	"Florida",
13:	"Georgia",
15:	"Hawaii",
16:	"Idaho",
17:	"Illinois",
18:	"Indiana",
19:	"Iowa",
20:	"Kansas",
21:	"Kentucky",
22:	"Louisiana",
23:	"Maine",
24:	"Maryland",
25:	"Massachusetts",
26:	"Michigan",
27:	"Minnesota",
28:	"Mississippi",
29:	"Missouri",
30:	"Montana",
31:	"Nebraska",
32:	"Nevada",
33:	"New Hampshire",
34:	"New Jersey",
35:	"New Mexico",
36:	"New York",
37:	"North Carolina",
38:	"North Dakota",
39:	"Ohio",
40:	"Oklahoma",
41:	"Oregon",
42:	"Pennsylvania",
44:	"Rhode Island",
45:	"South Carolina",
46:	"South Dakota",
47:	"Tennessee",
48:	"Texas",
49:	"Utah",
50:	"Vermont",
51:	"Virginia",
53:	"Washington",
54:	"West Virginia",
55:	"Wisconsin",
56:	"Wyoming",
}

# %%
data["STATEFIP"] = data["STATEFIP"].map(state_labels)
print(data.head())
data.to_csv('updated_Annual.csv')
# Out:
#    YEAR  SERIAL  MONTH REGION STATEFIP  COUNTY  AGE     SEX   RACE  HISPAN  \
# 0  2013       1      1  SOUTH  Alabama       0   79    male  White       0
# 1  2013       1      1  SOUTH  Alabama       0   65  female  White       0
# 2  2013       1      1  SOUTH  Alabama       0   28  female  White       0
# 3  2013       2      1  SOUTH  Alabama       0   32    male  White       0
# 4  2013       2      1  SOUTH  Alabama       0   33  female  White       0
#
#    EMPSTAT  WHYUNEMP  EDUC DIFFANY
# 0       36         0   111      NO
# 1       36         0   111      NO
# 2       10         0   111      NO
# 3       36         0    73     YES
# 4       36         0    73      NO

# %%
whyunemp_labels ={
0:	"NIU",
1:	"Job loser/ on layoff",
2:	"Other job loser",
3:	"Temporary job ended",
4:	"Job leaver",
5:	"Re-entrant",
6:	"New-entrant",
}

# %%
data["WHYUNEMP"] = data["WHYUNEMP"].map(whyunemp_labels)
print(data.head())
data.to_csv('updated_Annual.csv')
# Out:
#    YEAR  SERIAL  MONTH REGION STATEFIP  COUNTY  AGE     SEX   RACE  HISPAN  \
# 0  2013       1      1  SOUTH  Alabama       0   79    male  White       0
# 1  2013       1      1  SOUTH  Alabama       0   65  female  White       0
# 2  2013       1      1  SOUTH  Alabama       0   28  female  White       0
# 3  2013       2      1  SOUTH  Alabama       0   32    male  White       0
# 4  2013       2      1  SOUTH  Alabama       0   33  female  White       0
#
#    EMPSTAT WHYUNEMP  EDUC DIFFANY
# 0       36      NIU   111      NO
# 1       36      NIU   111      NO
# 2       10      NIU   111      NO
# 3       36      NIU    73     YES
# 4       36      NIU    73      NO

# %%
empstat_labels ={
1:	"Employed",	
10:	"Employed",
12:	"Employed",
21:	"Unemployed",
22:	"Unemployed",
}

# %%
data["EMPSTAT"] = data["EMPSTAT"].map(empstat_labels)
print(data.head())
data.to_csv('updated_Annual.csv')
# Out:
#    YEAR  SERIAL  MONTH REGION STATEFIP  COUNTY  AGE     SEX   RACE  HISPAN  \
# 0  2013       1      1  SOUTH  Alabama       0   79    male  White       0
# 1  2013       1      1  SOUTH  Alabama       0   65  female  White       0
# 2  2013       1      1  SOUTH  Alabama       0   28  female  White       0
# 3  2013       2      1  SOUTH  Alabama       0   32    male  White       0
# 4  2013       2      1  SOUTH  Alabama       0   33  female  White       0
#
#     EMPSTAT WHYUNEMP  EDUC DIFFANY
# 0       NaN      NIU   111      NO
# 1       NaN      NIU   111      NO
# 2  Employed      NIU   111      NO
# 3       NaN      NIU    73     YES
# 4       NaN      NIU    73      NO

# %%
educ_labels = {
2: "Dropout",
10: "Dropout",
20: "Dropout",
30:  "Dropout",
40: "Dropout",
50: "Dropout",
50: "Dropout",
60: "Dropout",
71: "Dropout",
73: "High School",
81: "Associate",
91: "Associate",
92: "Associate",
111: "Graduate",
123: "Graduate",
124: "Graduate",
125: "Graduate",
}

# %%
data["EDUC"] = data["EDUC"].map(educ_labels)
print(data.head())
data.to_csv('updated_Annual.csv')
# Out:
#    YEAR  SERIAL  MONTH REGION STATEFIP  COUNTY  AGE     SEX   RACE  HISPAN  \
# 0  2013       1      1  SOUTH  Alabama       0   79    male  White       0
# 1  2013       1      1  SOUTH  Alabama       0   65  female  White       0
# 2  2013       1      1  SOUTH  Alabama       0   28  female  White       0
# 3  2013       2      1  SOUTH  Alabama       0   32    male  White       0
# 4  2013       2      1  SOUTH  Alabama       0   33  female  White       0
#
#     EMPSTAT WHYUNEMP         EDUC DIFFANY
# 0       NaN      NIU     Graduate      NO
# 1       NaN      NIU     Graduate      NO
# 2  Employed      NIU     Graduate      NO
# 3       NaN      NIU  High School     YES
# 4       NaN      NIU  High School      NO

# %%
month_labels= {
    1: "Jan",
    2: "Feb",
    3: "Mar",
    4: "Apr",
    5: "May",
    6: "Jun",
    7: "Jul",
    8: "Aug",
    9: "Sep",
    10: "Oct",
    11: "Nov",
    12: "Dec"
}

# %%
from collections import defaultdict
def make_human_dictionary():
    
    dict=defaultdict(int)
    for index, row in data.iterrows():
        # race=row["RACE"]
        # l=["White","Black","Asian", "Hawaiian/Pacific Islander"]
        # if(race not in l):
            # race="Others"
        key=str(row["YEAR"])+"_"+month_labels[row["MONTH"]]+"_"+row["STATEFIP"]+"_"+row["RACE"]
        dict[key]+=1
    
    return dict
with open("a.txt","w") as f:
    f.write(str((make_human_dictionary())))

# %%
state_check = ["Alabama", "Alaska",
"Arizona",
"Arkansas",
"California",
"Colorado",
"Connecticut",
"Delaware",
"District of Columbia",
"Florida",
"Georgia",
"Hawaii",
"Idaho",
"Illinois",
"Indiana",
"Iowa",
"Kansas",
"Kentucky",
"Louisiana",
"Maine",
"Maryland",
"Massachusetts",
"Michigan",
"Minnesota",
"Mississippi",
"Missouri",
"Montana",
"Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico",
"New York",
"North Carolina",
"North Dakota",
"Ohio",
"Oklahoma",
"Oregon",
"Pennsylvania",
"Rhode Island",
"South Carolina",
"South Dakota",
"Tennessee",
"Texas",
"Utah",
"Vermont",
"Virginia",
"Washington",
"West Virginia",
"Wisconsin",
"Wyoming"]

data = make_human_dictionary()

for i in state_check:
    if str(i) in str(data.keys()):
        print(str(data.keys()))

# %%
import matplotlib as plt
state_race_dict = {}

race_check = ["White", "Black", "Asian", "Others"]

for i in state_check:
    for j in race_check:
        state_race_dict[str(i)+"_"+str(j)] = []

print(state_race_dict)

for i in state_race_dict:
    for key in data:
        if str(i) in str(key):
            state_race_dict[i].append(data[key])

print(state_race_dict)
# Out:
# {'Alabama_White': [], 'Alabama_Black': [], 'Alabama_Asian': [], 'Alabama_Others': [], 'Alaska_White': [], 'Alaska_Black': [], 'Alaska_Asian': [], 'Alaska_Others': [], 'Arizona_White': [], 'Arizona_Black': [], 'Arizona_Asian': [], 'Arizona_Others': [], 'Arkansas_White': [], 'Arkansas_Black': [], 'Arkansas_Asian': [], 'Arkansas_Others': [], 'California_White': [], 'California_Black': [], 'California_Asian': [], 'California_Others': [], 'Colorado_White': [], 'Colorado_Black': [], 'Colorado_Asian': [], 'Colorado_Others': [], 'Connecticut_White': [], 'Connecticut_Black': [], 'Connecticut_Asian': [], 'Connecticut_Others': [], 'Delaware_White': [], 'Delaware_Black': [], 'Delaware_Asian': [], 'Delaware_Others': [], 'District of Columbia_White': [], 'District of Columbia_Black': [], 'District of Columbia_Asian': [], 'District of Columbia_Others': [], 'Florida_White': [], 'Florida_Black': [], 'Florida_Asian': [], 'Florida_Others': [], 'Georgia_White': [], 'Georgia_Black': [], 'Georgia_Asian': 
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

Years  = ["2013", "2014", "2015",  "2016", "2017"]
Months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

x = list()
for i in Years:
    for j in Months:
        x.append(str(i) + "-" + str(j))
histogram_black = {}
for i in state_check:

    y_white = state_race_dict[str(i) + "_White"][:60]
    y_black = state_race_dict[str(i) + "_Black"][:60]
    y_asian = state_race_dict[str(i) + "_Asian"][:60]
    y_other = state_race_dict[str(i) + "_Others"][:60]
    # first plot with X and Y data
    x_size = len(x)
    if x_size != len(y_white) or x_size != len(y_black) or x_size != len(y_asian) or x_size != len(y_other):
        continue
    plt.plot(x, y_black, label="black")
    plt.plot(x, y_white, label="white")
    plt.plot(x, y_asian, label="asian")
    plt.plot(x, y_other, label="other")
    sum = y_white + y_black + y_asian + y_other
    histogram_data = y_black*100/sum
    histogram_black[str(i)] = histogram_data
    plt.tick_params(axis="x", rotation=80)
    plt.legend()
    
    plt.xlabel("X-axis data")
    plt.ylabel("Y-axis data")
    plt.title(str(i))
    plt.figure().set_figwidth(100)
    
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Years  = ["2013", "2014", "2015",  "2016", "2017"]
Months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

x = list()
for i in Years:
    for j in Months:
        x.append(str(i) + "-" + str(j))
histogram_black = {}
for i in state_check:

    y_white = state_race_dict[str(i) + "_White"][:60]
    y_black = state_race_dict[str(i) + "_Black"][:60]
    y_asian = state_race_dict[str(i) + "_Asian"][:60]
    y_other = state_race_dict[str(i) + "_Others"][:60]
    # first plot with X and Y data
    x_size = len(x)
    if x_size != len(y_white) or x_size != len(y_black) or x_size != len(y_asian) or x_size != len(y_other):
        continue
    # plt.plot(x, y_black, label="black")
    # plt.plot(x, y_white, label="white")
    # plt.plot(x, y_asian, label="asian")
    # plt.plot(x, y_other, label="other")
    y_white = np.array(y_white)
    y_black = np.array(y_black)
    y_other = np.array(y_other)
    y_asian = np.array(y_asian)
    sum = np.sum(y_white) + np.sum(y_black) + np.sum(y_asian) + np.sum(y_other)
    histogram_data = np.sum(y_black)*100/sum
    histogram_black[str(i)] = histogram_data
    # plt.tick_params(axis="x", rotation=80)
    # plt.legend()
    
    # plt.xlabel("X-axis data")
    # plt.ylabel("Y-axis data")
    # plt.title(str(i))
    # plt.figure().set_figwidth(100)
    
    # plt.show()
plt.bar(histogram_black.keys(), histogram_black.values(), color='c')

# %%
df = pd.read_csv('deaths.csv')
df['total_cases'] =  df['deaths'] +df['injured'] 
print(df.head())
# Out:
#    month  year       state  deaths  injured  total_cases
# 0  April  2013     Alabama       0        0            0
# 1  April  2013      Alaska       0        0            0
# 2  April  2013     Arizona       2        4            6
# 3  April  2013    Arkansas       0        0            0
# 4  April  2013  California       1        7            8

# %%
state_check = ["Alabama", "Alaska",
"Arizona",
"Arkansas",
"California",
"Colorado",
"Connecticut",
"Delaware",
"District of Columbia",
"Florida",
"Georgia",
"Hawaii",
"Idaho",
"Illinois",
"Indiana",
"Iowa",
"Kansas",
"Kentucky",
"Louisiana",
"Maine",
"Maryland",
"Massachusetts",
"Michigan",
"Minnesota",
"Mississippi",
"Missouri",
"Montana",
"Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico",
"New York",
"North Carolina",
"North Dakota",
"Ohio",
"Oklahoma",
"Oregon",
"Pennsylvania",
"Rhode Island",
"South Carolina",
"South Dakota",
"Tennessee",
"Texas",
"Utah",
"Vermont",
"Virginia",
"Washington",
"West Virginia",
"Wisconsin",
"Wyoming"]

# %%
state = ["Alabama", "Alaska",
"Arizona",
"Arkansas",
"California",
"Colorado",
"Connecticut",
"Delaware",
"District of Columbia",
"Florida",
"Georgia",
"Hawaii",
"Idaho",
"Illinois",
"Indiana",
"Iowa",
"Kansas",
"Kentucky",
"Louisiana",
"Maine",
"Maryland",
"Massachusetts",
"Michigan",
"Minnesota",
"Mississippi",
"Missouri",
"Montana",
"Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico",
"New York",
"North Carolina",
"North Dakota",
"Ohio",
"Oklahoma",
"Oregon",
"Pennsylvania",
"Rhode Island",
"South Carolina",
"South Dakota",
"Tennessee",
"Texas",
"Utah",
"Vermont",
"Virginia",
"Washington",
"West Virginia",
"Wisconsin",
"Wyoming"]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert month and year columns to datetime format and set as index
df['date'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'])
df = df.set_index('date')

# Filter the data for the required time period
start_date = '2013-04-01'
end_date = '2017-09-30'
df_filtered = df[(df.index >= start_date) & (df.index <= end_date)]

# Generate a sequence of dates for every month during the required time period
dates = pd.date_range(start=start_date, end=end_date, freq='MS')

# Loop over each state and create a new figure and subplot for each state
for state in df['state'].unique():
    df_state = df_filtered[df_filtered['state'] == state]['total_cases']
    df_state = df_state.reindex(dates, fill_value=0)
    fig, ax = plt.subplots()
    ax.plot(df_state.index, df_state.values)
    ax.set_title(f'Total Cases in {state} from April 2013 to September 2017')
    ax.set_xlabel('Date')
    ax.set_ylabel('Total Cases')
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert month and year columns to datetime format and set as index
df['date'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'])
df = df.set_index('date')

# Filter the data for the required time period
start_date = '2013-04-01'
end_date = '2017-09-30'
df_filtered = df[(df.index >= start_date) & (df.index <= end_date)]

# Generate a sequence of dates for every month during the required time period
dates = pd.date_range(start=start_date, end=end_date, freq='MS')

# # Loop over each state and create a new figure and subplot for each state
# for state in df['state'].unique():
#     df_state = df_filtered[df_filtered['state'] == state]['total_cases']
#     df_state = df_state.reindex(dates, fill_value=0)
#     fig, ax = plt.subplots()
#     ax.plot(df_state.index, df_state.values)
#     ax.set_title(f'Total Cases in {state} from April 2013 to September 2017')
#     ax.set_xlabel('Date')
#     ax.set_ylabel('Total Cases')
#     plt.show()
# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10,6))

# Loop over each state and add the data to the axis object
for state in df['state'].unique():
    df_state = df_filtered[df_filtered['state'] == state]['total_cases']
    df_state = df_state.reindex(dates, fill_value=0)
    ax.plot(df_state.index, df_state.values, label=state)

# Set the title, x-axis label, y-axis label, and legend
ax.set_title('Total Cases by State from April 2013 to September 2017')
ax.set_xlabel('Date')
ax.set_ylabel('Total Cases')
ax.legend(loc='upper left', bbox_to_anchor=(1.02, 1))


# Display the plot
plt.show()
_

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert month and year columns to datetime format and set as index
df['date'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'])
df = df.set_index('date')

# Filter the data for the required time period
start_date = '2013-04-01'
end_date = '2017-09-30'
df_filtered = df[(df.index >= start_date) & (df.index <= end_date)]

# Generate a sequence of dates for every month during the required time period
dates = pd.date_range(start=start_date, end=end_date, freq='MS')

x = list()
new_Years = ["2013", "2014", "2015", "2016", "2017"]
for i in new_Years:
    for j in Months:
        x.append(str(i) + "-" + str(j))
print(x)

# Loop over each state and create a new figure and subplot for each state
for state in df['state'].unique():

    curr_df = df[df['state'] == state]

    fig, ax1 = plt.subplots()

    new_y_white = state_race_dict[state.replace(' ', '-') + "_White"]
    new_y_black = state_race_dict[state.replace(' ', '-') + "_Black"]
    new_y_asian = state_race_dict[state.replace(' ', '-') + "_Asian"]
    new_y_other = state_race_dict[state.replace(' ', '-') + "_Others"]
    ax1.plot(x, new_y_black, label="black")
    ax1.plot(x, new_y_white, label="white")
    ax1.plot(x, new_y_asian, label="asian")
    ax1.plot(x, new_y_other, label="other")
    ax1.tick_params(axis="x", rotation=80)
    ax1.legend()

    ax2 = ax1.twinx()
    hurts = list()
    for year in range(2013, 2018):
        curr_year_df = curr_df[curr_df['year'] == year]
        for month in Months:
            curr_month_df = curr_year_df[curr_year_df['month'] == month]
            hurts.append(df['deaths'])
    print(len(x), len(hurts))
    ax2.plot(x, hurts)
    fig.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# state_check = ["Alabama", "Alaska",
# "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "District of Columbia", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", 
# "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", 
# "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon",
# "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee",
# "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"]

# data = make_human_dictionary()

# Data for the first graph
Years = ["2013", "2014", "2015", "2016", "2017", "2018"]
Months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

x = list()
for i in Years:
    for j in Months:
        x.append(str(i) + "-" + str(j))

# state_check = ["State1", "State2", "State3", "State4"]

for i in state_check:
    y_white = state_race_dict[str(i) + "_White"]
    y_black = state_race_dict[str(i) + "_Black"]
    y_asian = state_race_dict[str(i) + "_Asian"]
    y_other = state_race_dict[str(i) + "_Others"]

    # Create a subplot for the first graph
    plt.subplot(211)
    plt.plot(x, y_black, label="black")
    plt.plot(x, y_white, label="white")
    plt.plot(x, y_asian, label="asian")
    plt.plot(x, y_other, label="other")
    plt.tick_params(axis="x", rotation=80)
    # plt.legend()
    plt.xlabel("X-axis data")
    plt.ylabel("Y-axis data")
    plt.title(str(i))

# Data for the second graph
df = pd.read_csv('deaths.csv')
df['total_cases'] =  df['deaths'] +df['injured'] 


# Convert month and year columns to datetime format and set as index
df['date'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'])
df = df.set_index('date')

# Filter the data for the required time period
start_date = '2013-04-01'
end_date = '2017-09-30'
df_filtered = df[(df.index >= start_date) & (df.index <= end_date)]

# Generate a sequence of dates for every month during the required time period
dates = pd.date_range(start=start_date, end=end_date, freq='MS')

for state in df['state'].unique():
    df_state = df_filtered[df_filtered['state'] == state]['total_cases']
    df_state = df_state.reindex(dates, fill_value=0)
    fig, ax2 = plt.subplots(212)
    ax2.plot(df_state.index, df_state.values, label = state)
    ax2.set_title(f'Total Cases in {state} from April 2013 to September 2017')
    ax2.set_xlabel('Date')
    ax2.set_ylabel('Total Cases')
    # plt.show()/



plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 34
#      32 # Create a subplot for the first graph
#      33 plt.subplot(211)
# ---> 34 plt.plot(x, y_black, label="black")
#      35 plt.plot(x, y_white, label="white")
#      36 plt.plot(x, y_asian, label="asian")
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# # Convert month and year columns to datetime format and set as index
# df['date'] = pd.to_datetime(df['year'].astype(str) + '-' + df['month'])
# df = df.set_index('date')

# # Filter the data for the required time period
# start_date = '2013-04-01'
# end_date = '2017-09-30'
# df_filtered = df[(df.index >= start_date) & (df.index <= end_date)]

# # Generate a sequence of dates for every month during the required time period
# dates = pd.date_range(start=start_date, end=end_date, freq='MS')

x = list()
for i in Years:
    for j in Months:
        x.append(str(i) + "-" + str(j))

# Loop over each state and create a new figure and subplot for each state
for state in df['state'].unique():

    curr_df = df[df['state'] == state]

    fig, ax1 = plt.subplots()

    # y_white = state_race_dict[state.replace(' ', '-') + "_White"][:60]
    y_black = state_race_dict[state.replace(' ', '-') + "_Black"][:60]
    # y_asian = state_race_dict[state.replace(' ', '-') + "_Asian"][:60]
    # y_other = state_race_dict[state.replace(' ', '-') + "_Others"][:60]
    ax1.plot(x, y_black, label="black")
    # ax1.plot(x, y_white, label="white")
    # ax1.plot(x, y_asian, label="asian")
    # ax1.plot(x, y_other, label="other")
    ax1.tick_params(axis="x", rotation=80)
    ax1.tick_params(axis='y', labelcolor='tab:red')
    ax1.legend()

    ax2 = ax1.twinx()
    hurts = list()
    for year in range(2013, 2018):
        curr_year_df = curr_df[curr_df['year'] == year]
        for month in Months:
            curr_month_df = curr_year_df[curr_year_df['month'] == month]
            hurts.append(df['deaths'])
    ax2.plot(x, hurts)
    print(hurts)
    ax2.tick_params(axis='y', labelcolor='tab:blue')
    fig.tight_layout()
    plt.show()
# Out:
# [date
# 2013-04-01     0
# 2013-04-01     0
# 2013-04-01     2
# 2013-04-01     0
# 2013-04-01     1
#               ..
# 2017-09-01    34
# 2017-09-01    24
# 2017-09-01     5
# 2017-09-01    20
# 2017-09-01     1
# Name: deaths, Length: 2940, dtype: int64, date
# 2013-04-01     0
# 2013-04-01     0
# 2013-04-01     2
# 2013-04-01     0
# 2013-04-01     1
#               ..
# 2017-09-01    34
# 2017-09-01    24
# 2017-09-01     5
# 2017-09-01    20
# 2017-09-01     1
# Name: deaths, Length: 2940, dtype: int64, date
# 2013-04-01     0
# 2013-04-01     0
# 2013-04-01     2
# 2013-04-01     0
# 2013-04-01     1
#               ..
# 2017-09-01    34
# 2017-09-01    24
# 2017-09-01     5
# 2017-09-01    20
# 2017-09-01     1
# Name: deaths, Length: 2940, dtype: int64, date
# 2013-04-01     0
# 2013-04-01     0
# 2013-04-01     2
# 2013-04-01     0
# 2013-04-01     1
#               ..
# 2017-09-01    34
# 2017-09-01    24
# 2017-09-01     5
# 2017-09-01    20
# 2017-09-01     1
# ...
